# %% [markdown]
# **Our chatbot**

# %% [markdown]
# This chatbot allows the user to log in and connect to the mySQL server using his/her credentials, to create a database or connect to an existing one and perform the actions of Show Tables, Create Table, Drop Table, Create View, Update View, Drop View, Insert, Update, Delete, Select as well as Exit the program and end the connection with the workbench.
#
# After choosing an action he can input the needed values and call the corresponding function with this input as parameter in order to create the query and execute it.

# %% [markdown]
# As mentioned in the Functions notebook, every function used has a query that the user fills with his input in this chatbot and the query is finally executed. The procedure in the chatbot follows questions about the values the user wants to use in each action, whether it is about connecting to the database or using one of the functions to affect a table, giving total freedom and control of the final query/result.

# %% [markdown]
# In each action and input in general there are failsafes that prevent the program from shutting down due to an error (error handling) in order for the bot to continue running and give the user the chance to repeat the procedure correctly this time.
#
# Every error brings the user back to the original question in order to try again.

# %% [markdown]
# Every action is simple and similar to almost all the others. Questions are asked for input and after proper processing of the input, error handling and calling the function the query is finally formed and executed. If the user is correct with his input, using correctly the commas and the quotations for strings as well as correct sql syntax there can be no misunderstanding of the procedure and no errors.
#
# However, the only complicated part in terms of coding and chatbot questions is the Select action as well as the Where conditions both in Update and Delete actions.
#
# In these cases, apart from the regular input, there is a chance that the user wants to create nested Select queries inside the Where conditions or inside the Select, From and Having conditions of the Select action, by using the special nested Select function which has the same code as the select action in the chatbot notebook with the only difference that it returns the created query without executing it. In this case the user MUST input the condition he wants but instead of typing all the nested select he should only type "()" (without the quotations). After moving to the next step, he will be asked to fill every nested select one by one in the previous condition and only when he finishes them all will he move to the next condition.
#
# E.g.: Select * From table Where column > () AND column2 < () Group By column3 = value
#
# In this scenario he will be asked the name of the table, the select condition, the where condition and after the system finds the "()" he will be asked to fill those nested select first one by one and possibly any other double nested select in them and THEN move on to the next condition, in our case Group By.
#
# Every condition that does not allow nested select queries does not make this extra step of looking for "()" but only the ones mentioned before. In case no "()" is found in the input, the procedure continues normally like any other action/condition.

# %%
# %run Functions.ipynb

print('Welcome to our ChatBot!\n')

while(1):
    print('Please connect to mySQL using your credentials.\n')
    
    sleep(0.3)
    
    host_name = input('Please type your host-name: ')
    user_name = input('Please type your user-name: ')
    password = input('Please type your password: ')
    
    try:
        db = ConnectMySQL(host_name, user_name, password)
        break
    except:
        print("\nAn error has occured. Please make sure you typed your credentials correctly and MySQL WorkBench is running.\n")

while(1):
    answer = input('\nIf you want to create a new database and connect to it please type "Yes" (without the quotations), otherwise type \n "No" (without the quotations) in order to connect to an existing one: ')
    if answer == 'Yes':
        db_name = input('Insert the name of the new database you want to create: ')
        
        try:
            CreateDB(db_name)
        except:
            print("\nAn error has occured. That database name already exists.")
            continue
        
        db = ConnectDB(host_name, user_name, password, db_name)
        break
           
    elif answer == 'No':
        print('\nHere are all the existing databases:\n')
        ShowDB()
        db_name = input('\nInsert the name of the existing database you want to connect to: ')
        
        try:
            db = ConnectDB(host_name, user_name, password, db_name)
            break
        except:
            print('\nAn error has occured. That database name does not exist.')
            continue
    else:
        print('\nYour input is incorrect, please type "Yes" or "No" (without the quotations).')
        
while(1):
    action = input('\nPlease choose one of the following actions:\nType "Show Tables" (without the quotations) in order to show the existing tables in the database.\nType "Create Table" (without the quotations) in order to create a new table.\nType "Drop Table" (without the quotations) in order to drop an existing table.\nType "Create View" (without the quotations) in order to create a new view.\nType "Update View" (without the quotations) in order to update an existing view.\nType "Drop View" (without the quotations) in order to drop an existing view.\nType "Insert" (without the quotations) in order to insert a new row into a table.\nType "Update" (without the quotations) in order to update a row from a table.\nType "Delete" (without the quotations) in order to delete a row from a table.\nType "Select" (without the quotations) in order to search for specific rows in a table\nType "Exit" (without the quotations) in order to exit the program and close the connection: ')
    
    if action == 'Show Tables':
        print('\nHere are the existing tables of',db_name,":\n")
        ShowTables()
        
    elif action == 'Create Table':
        table_name = input('\nPlease type the name of the table you want to create: ')
        table_values = list()
        columns = input('\nPlease type the column names of the table you want to create (separated by commas): ')
        table_values.append(columns)
        table_values = np.array(table_values)
        
        try:
            CreateTable(table_name,table_values)
        except:
            print('\nThere was an error in the query. Please try again.')
    
    elif action == 'Drop Table':
        table_name = input('\nPlease type the name of the table you want to drop: ')
        
        try:
            DropTable(table_name)
        except:
            print('\nThere was an error in the query. Please try again.')

    elif action == 'Create View':
        view_name = input('\nPlease type the name of the view you want to create: ')
        
        try:
            CreateView(view_name) 
        except:
            print('\nThere was an error in the query. Please try again.')            
            
    elif action == 'Drop View':
        view_name = input('\nPlease type the name of the view you want to drop: ')
        
        try:
            DropView(view_name)
        except:
            print('\nThere was an error in the query. Please try again.')
            
    elif action == 'Update View':
        view_name = input('\nPlease type the name of the view you want to update: ')
        
        try:
            UpdateView(view_name) 
        except:
            print('\nThere was an error in the query. Please try again.')         
    
    elif action == 'Insert':
        table_name = input('\nPlease type the name of the table you want to insert a new row to: ')
        table_values = list()
        columns = input('\nPlease type the column names of your selected table (separated by commas): ')
        table_values.append(columns)
        column_values = input('\nPlease type the values of each column of your selected table (separated by commas): ')
        table_values.append(column_values)
        table_values = np.array(table_values)
        
        try:
            Insert(table_name,table_values)
        except:
            print('\nThere was an error in the query. Please try again.')
            
    elif action == 'Update':
        table_name = input('\nPlease type the name of the table you want to update a row from: ')
        table_values = list()
        set_cond = input('\nPlease type the SET condition: ')
        table_values.append(set_cond)
        where_cond = input('\nPlease type the WHERE condition: ')
        
        query = list()
        j=0
        flag = 0
       
        for i in range(0,len(where_cond)):
            if where_cond[i] == '(':
                if i + 1 <= len(where_cond) - 1:
                    if where_cond[i+1] == ')':
                        flag = 1
                        query.append(where_cond[j:i+1])
                        nestedselect_cond = NestedSelect()
                        query.append(nestedselect_cond)
                        j = i+1
        if flag == 1:
            where_cond = ''
            for i in range(0,len(query)):
                where_cond = where_cond + query[i]
            where_cond = where_cond + ')'
        table_values.append(where_cond)
        table_values = np.array(table_values)
        
        try:
            Update(table_name,table_values)
        except:
            print('\nThere was an error in the query. Please try again.')
            
    elif action == 'Delete':
        table_name = input('\nPlease type the name of the table you want to delete a row from: ')
        table_values = list()
        where_cond = input('\nPlease type the WHERE condition: ')
        
        query = list()
        j=0
        flag = 0
        
        for i in range(0,len(where_cond)):
            if where_cond[i] == '(':
                if i + 1 <= len(where_cond) - 1:
                    if where_cond[i+1] == ')':
                        flag = 1
                        query.append(where_cond[j:i+1])
                        nestedselect_cond = NestedSelect()
                        query.append(nestedselect_cond)
                        j = i+1
        if flag == 1:
            where_cond = ''
            for i in range(0,len(query)):
                where_cond = where_cond + query[i]
            where_cond = where_cond + ')'
        table_values.append(where_cond)
        table_values = np.array(table_values)
        
        try:
            Delete(table_name,table_values) 
        except:
            print('\nThere was an error in the query. Please try again.')
            
    elif action == 'Select':
        table_name = input('\nPlease type the name of the table you want to select rows from: ')

        temp = list()
        j = 0
        flag = 0

        for i in range(0,len(table_name)):
            if table_name[i] == '(':
                if i + 1 <= len(table_name) - 1:
                    if table_name[i+1] == ')':
                        flag = 1
                        temp.append(table_name[j:i+1])
                        nestedselect_cond = NestedSelect()
                        temp.append(nestedselect_cond)
                        j = i + 1

        if flag == 1:
            table_name = ''
            for i in range(0,len(temp)):
                table_name = table_name + temp[i]
            table_name = table_name + ')'

        table_values = list()

        select_cond = input('\nPlease type the SELECT condition: ')

        temp = list()
        j=0
        flag = 0

        for i in range(0,len(select_cond)):
            if select_cond[i] == '(':
                if i + 1 <= len(select_cond) - 1:
                    if select_cond[i+1] == ')':
                        flag = 1
                        temp.append(select_cond[j:i+1])
                        nestedselect_cond = NestedSelect()
                        temp.append(nestedselect_cond)
                        j = i + 1
        if flag == 1:
            select_cond = ''
            for i in range(0,len(temp)):
                select_cond = select_cond + temp[i]
            select_cond = select_cond + ')'

        table_values.append(select_cond)

        while(1):
            answer = input('\nWill you use a WHERE condition? Please type "Yes" or "No" (without the quotations).')
            if answer == 'Yes':
                where_cond = input('\nPlease type the WHERE condition: ')
                where_cond = 'WHERE ' + where_cond

                temp = list()
                j=0
                flag = 0

                for i in range(0,len(where_cond)):
                    if where_cond[i] == '(':
                        if i + 1 <= len(where_cond) - 1:
                            if where_cond[i+1] == ')':
                                flag = 1
                                temp.append(where_cond[j:i+1])
                                nestedselect_cond = NestedSelect()
                                temp.append(nestedselect_cond)
                                j = i+1

                if flag == 1:
                    where_cond = ''
                    for i in range(0,len(temp)):
                        where_cond = where_cond + temp[i]
                    where_cond = where_cond + ')'

                table_values.append(where_cond)
                break

            elif answer == 'No':
                where_cond = ''
                table_values.append(where_cond)
                break

            else:
                 print('\nYour input is incorrect, please type "Yes" or "No" (without the quotations).')

        while(1):
            answer = input('\nWill you use a GROUP BY condition? Please type "Yes" or "No" (without the quotations).')
            if answer == 'Yes':
                groupby_cond = input('\nPlease type the GROUP BY condition: ')
                groupby_cond = 'GROUP BY ' + groupby_cond
                table_values.append(groupby_cond)
                break

            elif answer == 'No':
                groupby_cond = ''
                table_values.append(groupby_cond)
                break

            else:
                 print('\nYour input is incorrect, please type "Yes" or "No" (without the quotations).')    

        if answer == 'Yes':
            while(1):
                answer = input('\nWill you use a HAVING condition? Please type "Yes" or "No" (without the quotations).')
                if answer == 'Yes':
                    having_cond = input('\nPlease type the HAVING condition: ')
                    having_cond = 'HAVING ' + having_cond

                    temp = list()
                    j=0
                    flag = 0

                    for i in range(0,len(having_cond)):
                        if having_cond[i] == '(':
                            if i + 1 <= len(having_cond) - 1:
                                if having_cond[i+1] == ')':
                                    flag = 1
                                    temp.append(having_cond[j:i+1])
                                    nestedselect_cond = NestedSelect()
                                    temp.append(nestedselect_cond)
                                    j = i+1

                    if flag == 1:
                        having_cond = ''
                        for i in range(0,len(temp)):
                            having_cond = where_cond + temp[i]
                        having_cond = having_cond + ')'

                    table_values.append(having_cond)
                    break

                elif answer == 'No':
                    having_cond = ''
                    table_values.append(having_cond)
                    break

                else:
                     print('\nYour input is incorrect, please type "Yes" or "No" (without the quotations).')

        else:
            having_cond = ''
            table_values.append(having_cond)

        while(1):
            answer = input('\nWill you use an ORDER BY condition? Please type "Yes" or "No" (without the quotations).')
            if answer == 'Yes':
                orderby_cond = input('\nPlease type the ORDER BY condition: ')
                orderby_cond = 'ORDER BY ' + orderby_cond
                table_values.append(orderby_cond)
                break

            elif answer == 'No':
                orderby_cond = ''
                table_values.append(orderby_cond)
                break

            else:
                 print('\nYour input is incorrect, please type "Yes" or "No" (without the quotations).')

        table_values = np.array(table_values)
        
        try:
            rows,headers = Select(table_name,table_values) 
        except:
            print('\nThere was an error in the query. Please try again.')
            continue
        
        rows = np.array(rows)
        
        print("\n")
        

        temp = list()
        for i in range(0,len(headers)):
            temp.append(headers[i])
        df=DataFrame(rows,columns=temp) 
        display(df)
        sleep(1)
        
    elif action == 'Exit':
        Exit()
        print('\nThank you for using our ChatBot. Have a nice day!')
        break
    
    else: 
        print('\nYour input is incorrect, please type "Insert", "Update", "Delete", "Select", "Create View" or "Exit" (without the \nquotations).')
# Out:
# Welcome to our ChatBot!
#
# Please connect to mySQL using your credentials.
#
# Please type your host-name: localhost
# Please type your user-name: root
# Please type your password: psafg
#
# An error has occured. Please make sure you typed your credentials correctly and MySQL WorkBench is running.
#
# Please connect to mySQL using your credentials.
#
# Please type your host-name: localhost
# Please type your user-name: root
# Please type your password: password
# <mysql.connector.connection.MySQLConnection object at 0x000001A64EE42548>
#
# If you want to create a new database and connect to it please type "Yes" (without the quotations), otherwise type
#  "No" (without the quotations) in order to connect to an existing one: No
#
# Here are all the existing databases:
#
# [('coronavirustrump',), ('covidtrump',), ('dbs2',), ('information_schema',), ('latestdata',), ('mysql',), ('performance_schema',), ('sakila',), ('sys',), ('tempdb',), ('temporal',), ('test',), ('test1',), ('test2',), ('test3',), ('testdb',), ('world',)]
#
# Insert the name of the existing database you want to connect to: dbs2
#
# Please choose one of the following actions:
# Type "Show Tables" (without the quotations) in order to show the existing tables in the database.
# Type "Create Table" (without the quotations) in order to create a new table.
# Type "Drop Table" (without the quotations) in order to drop an existing table.
# Type "Create View" (without the quotations) in order to create a new view.
# Type "Update View" (without the quotations) in order to update an existing view.
# Type "Drop View" (without the quotations) in order to drop an existing view.
# Type "Insert" (without the quotations) in order to insert a new row into a table.
# Type "Update" (without the quotations) in order to update a row from a table.
# Type "Delete" (without the quotations) in order to delete a row from a table.
# Type "Select" (without the quotations) in order to search for specific rows in a table
# Type "Exit" (without the quotations) in order to exit the program and close the connection: Select
#
# Please type the name of the table you want to select rows from: nba_stats19_20
#
# Please type the SELECT condition: *
#
# Will you use a WHERE condition? Please type "Yes" or "No" (without the quotations).No
#
# Will you use a GROUP BY condition? Please type "Yes" or "No" (without the quotations).No
#
# Will you use an ORDER BY condition? Please type "Yes" or "No" (without the quotations).No
#
# The query you created is:
#
# SELECT * FROM nba_stats19_20
#       ID        Name             Surname    Pos Age   Tm   G    MP    FG  \
# 0      1       James              Harden     SG  30  HOU  68  36.5   9.9
# 1      2     Bradley                Beal     SG  26  WAS  57  36.0  10.4
# 2      3      Damian             Lillard     PG  29  POR  66  37.5   9.5
# 3      4        Trae               Young     PG  21  ATL  60  35.3   9.1
# 4      5     Giannis       Antetokounmpo     PF  25  MIL  63  30.4  10.9
# 5      6        Luka              Dončić     PG  20  DAL  61  33.6   9.5
# 6      7     Russell           Westbrook     PG  31  HOU  57  35.9  10.6
# 7      8       Kawhi             Leonard     SF  28  LAC  57  32.4   9.3
# 8      9       Devin              Booker     SG  23  PHO  70  35.9   9.0
# 9     10     Anthony               Davis     PF  26  LAL  62  34.4   8.9
# 10    11        Zach              LaVine     SG  24  CHI  60  34.8   9.0
# 11    12      LeBron               James     PG  35  LAL  67  34.6   9.6
# 12    13     Donovan            Mitchell     SG  23  UTA  69  34.3   8.7
# 13    14     Brandon              Ingram     PF  22  NOP  62  33.9   8.2
# 14    15      Jayson               Tatum     PF  21  BOS  66  34.3   8.4
# 15    16      Pascal              Siakam     PF  25  TOR  60  35.2   8.3
# 16    17          CJ            McCollum     SG  28  POR  70  36.5   8.7
# 17    18       DeMar             DeRozan     SF  30  SAS  68  34.1   8.2
# 18    19      Andrew             Wiggins     SF  24  TOT  54  34.4   8.1
# 19    20    De'Aaron                 Fox     PG  22  SAC  51  32.0   7.7
# 20    21       Khris           Middleton     SF  28  MIL  62  29.9   7.6
# 21    22      Collin              Sexton     PG  21  CLE  65  33.0   7.9
# 22    23     Spencer           Dinwiddie     PG  26  BRK  64  31.2   6.6
# 23    24    Kristaps           Porziņģis      C  24  DAL  57  31.8   7.0
# 24    25       Kemba              Walker     PG  29  BOS  56  31.1   6.8
# 25    26      Jaylen               Brown     SG  23  BOS  57  33.9   7.5
# 26    27       Bojan          Bogdanović     SF  30  UTA  63  33.1   6.6
# 27    28       Jimmy              Butler     SF  30  MIA  58  33.8   5.9
# 28    29      Nikola               Jokić      C  24  DEN  73  32.0   7.7
# 29    30        T.J.              Warren     SF  26  IND  67  32.9   8.0
# 30    31      Tobias              Harris     PF  27  PHI  72  34.3   7.7
# 31    32      Nikola             Vučević      C  29  ORL  62  32.2   8.0
# 32    33      Julius              Randle     PF  25  NYK  64  32.5   7.2
# 33    34        Kyle               Lowry     PG  33  TOR  58  36.2   5.8
# 34    35       Buddy               Hield     SG  27  SAC  72  30.8   6.9
# 35    36        Jrue             Holiday     SG  29  NOP  61  34.7   7.5
# 36    37        Shai  Gilgeous-Alexander     SG  21  OKC  70  34.7   6.8
# 37    38    LaMarcus            Aldridge      C  34  SAS  53  33.1   7.4
# 38    39      Dennis            Schröder     SG  26  OKC  65  30.8   7.0
# 39    40      Danilo           Gallinari     PF  31  OKC  62  29.6   5.8
# 40    41       Kelly               Oubre     SF  24  PHO  56  34.5   6.7
# 41    42    Montrezl             Harrell      C  26  LAC  63  27.8   7.5
# 42    43        Evan            Fournier     SF  27  ORL  66  31.5   6.6
# 43    44       Jamal              Murray     PG  22  DEN  59  32.3   6.9
# 44    45    Domantas             Sabonis     PF  23  IND  62  34.8   7.4
# 45    46    Devonte'              Graham     PG  24  CHO  63  35.1   5.8
# 46    47         Lou            Williams     PG  33  LAC  65  28.7   6.0
# 47    48     Derrick                Rose     PG  31  DET  50  26.0   7.4
# 48    49       Terry              Rozier     PG  25  CHO  63  34.3   6.3
# 49    50          Ja              Morant     PG  20  MEM  67  31.0   6.7
# 50    51       Andre            Drummond      C  26  TOT  57  33.0   7.3
# 51    52       Kevin                Love     PF  31  CLE  56  31.8   5.8
# 52    53       Chris                Paul     PG  34  OKC  70  31.5   6.2
# 53    54        Fred            VanVleet     SG  25  TOR  54  35.7   5.9
# 54    55      Gordon             Hayward     SF  29  BOS  52  33.5   6.7
# 55    56       Jaren             Jackson      C  20  MEM  57  28.5   6.2
# 56    57      Marcus              Morris  SF-PF  30  TOT  62  31.2   5.7
# 57    58     Malcolm             Brogdon     PG  27  IND  54  30.9   6.0
# 58    59         Ben             Simmons     PG  23  PHI  57  35.4   6.6
# 59    60      Dillon              Brooks     SG  24  MEM  73  28.9   6.0
# 60    61       Goran              Dragić     PG  33  MIA  59  28.2   5.4
# 61    62      Norman              Powell     SG  26  TOR  52  28.4   5.7
# 62    63         Bam             Adebayo     PF  22  MIA  72  33.6   6.1
# 63    64         Tim            Hardaway     SG  27  DAL  71  29.5   5.4
# 64    65      Hassan           Whiteside      C  30  POR  67  30.0   6.5
# 65    66     Carmelo             Anthony     PF  35  POR  58  32.8   5.8
# 66    67       Dāvis             Bertāns     PF  27  WAS  54  29.3   4.9
# 67    68       Serge               Ibaka      C  30  TOR  55  27.0   6.2
# 68    69    Kendrick                Nunn     PG  24  MIA  67  29.3   6.0
# 69    70        J.J.              Redick     SG  35  NOP  60  26.4   4.8
# 70    71      Jordan            Clarkson     SG  27  TOT  71  24.0   5.5
# 71    72        Will              Barton     SF  29  DEN  58  33.0   5.7
# 72    73      Bogdan          Bogdanović     SG  27  SAC  61  29.0   5.5
# 73    74        Rudy              Gobert      C  27  UTA  68  34.3   5.7
# 74    75        Alec               Burks  SF-SG  28  TOT  66  26.6   4.9
# 75    76        Eric             Bledsoe     PG  30  MIL  61  27.0   5.5
# 76    77       Jonas         Valančiūnas      C  27  MEM  70  26.4   6.2
# 77    78       Lauri           Markkanen     PF  22  CHI  50  29.8   5.0
# 78    79    Terrence                Ross     SG  28  ORL  69  27.4   4.9
# 79    80    Harrison              Barnes     PF  27  SAC  72  34.5   5.1
# 80    81         Joe              Harris     SF  28  BRK  69  30.8   5.5
# 81    82       Aaron              Gordon     PF  24  ORL  62  32.5   5.4
# 82    83          RJ             Barrett     SG  19  NYK  56  30.4   5.2
# 83    84        Eric            Paschall     PF  23  GSW  60  27.6   5.3
# 84    85        Josh          Richardson     SG  26  PHI  55  30.8   5.1
# 85    86       Tyler               Herro     SG  20  MIA  55  27.4   4.9
# 86    87      Duncan            Robinson     SG  25  MIA  73  29.7   4.4
# 87    88        Coby               White     PG  19  CHI  65  25.8   4.8
# 88    89   Christian                Wood     PF  24  DET  62  21.4   4.6
# 89    90       Miles             Bridges     SF  21  CHO  65  30.7   4.9
# 90    91       Ricky               Rubio     PG  29  PHO  65  31.0   4.4
# 91    92      Marcus               Smart     SG  25  BOS  60  32.0   4.3
# 92    93        Kyle               Kuzma     PF  24  LAL  61  25.0   4.8
# 93    94      Damion                 Lee     SG  27  GSW  49  29.0   4.3
# 94    95      Robert           Covington   PF-C  29  TOT  70  30.5   4.4
# 95    96        Seth               Curry     SG  29  DAL  64  24.6   4.4
# 96    97      Darius             Garland     SG  20  CLE  59  30.9   4.7
# 97    98    De'Andre              Hunter     SF  22  ATL  63  32.0   4.4
# 98    99       Kevin             Huerter     SG  21  ATL  56  31.4   4.5
# 99   100        P.J.          Washington     PF  21  CHO  58  30.3   4.6
# 100  101     Brandon              Clarke     PF  23  MEM  58  22.4   5.1
# 101  102    Markelle               Fultz     PG  21  ORL  72  27.7   5.0
# 102  103     Taurean              Prince     PF  25  BRK  64  29.0   4.3
# 103  104       Myles              Turner      C  23  IND  62  29.5   4.3
# 104  105      Jerami               Grant     PF  25  DEN  71  26.6   4.3
# 105  106       Brook               Lopez      C  31  MIL  68  26.7   4.3
# 106  107     Tristan            Thompson     PF  28  CLE  57  30.2   5.1
# 107  108          Al             Horford      C  33  PHI  67  30.2   4.8
# 108  109       Lonzo                Ball     PG  22  NOP  63  32.1   4.4
# 109  110       Glenn            Robinson     SF  26  TOT  62  28.8   4.6
# 110  111       Patty               Mills     PG  31  SAS  66  22.5   3.9
# 111  112     Nemanja             Bjelica     PF  31  SAC  72  27.9   4.4
# 112  113     Derrick               White     SG  25  SAS  68  24.7   3.7
# 113  114       Malik             Beasley     SG  23  TOT  55  22.0   4.1
# 114  115        Bryn              Forbes     SG  26  SAS  63  25.1   3.8
# 115  116     Jarrett               Allen      C  21  BRK  70  26.5   4.3
# 116  117        Cody              Zeller      C  27  CHO  58  23.1   4.3
# 117  118        Cedi               Osman     SF  24  CLE  65  29.4   4.1
# 118  119      Steven               Adams      C  26  OKC  63  26.7   4.5
# 119  120    Dejounte              Murray     PG  23  SAS  66  25.6   4.5
# 120  121         Ish               Smith     PG  31  WAS  68  26.3   4.5
# 121  122        Jeff              Teague     PG  31  TOT  59  24.8   3.6
# 122  123        Rudy                 Gay     PF  33  SAS  67  21.8   4.0
# 123  124       Dario               Šarić     PF  25  PHO  66  24.7   3.9
# 124  125          OG             Anunoby     SF  22  TOR  69  29.9   4.1
# 125  126        D.J.            Augustin     PG  32  ORL  57  24.9   3.2
# 126  127         Jae             Crowder  SF-PF  29  TOT  65  28.8   3.5
# 127  128      Danuel               House     SF  26  HOU  63  30.4   3.7
# 128  129         Cam             Reddish     SF  20  ATL  58  26.7   3.7
# 129  130        Troy               Brown     SF  20  WAS  69  25.8   4.0
# 130  131        Gary              Harris     SG  25  DEN  56  31.8   3.9
# 131  132    Langston            Galloway     SG  28  DET  66  25.8   3.6
# 132  133        Doug           McDermott     PF  28  IND  69  19.9   3.9
# 133  134       Malik                Monk     SG  21  CHO  55  21.3   3.9
# 134  135     Shabazz              Napier     PG  28  TOT  56  24.0   3.4
# 135  136     Garrett              Temple     SG  33  BRK  62  27.9   3.6
# 136  137    Thaddeus               Young     PF  31  CHI  64  24.9   4.2
# 137  138        Josh                Hart     SF  24  NOP  65  27.0   3.5
# 138  139         Ben            McLemore     SF  26  HOU  71  22.8   3.4
# 139  140       Larry               Nance     PF  27  CLE  56  26.3   4.1
# 140  141       Bobby              Portis     PF  24  NYK  66  21.1   4.0
# 141  142       Kevin              Porter     SF  19  CLE  50  23.2   3.7
# 142  143       Tomáš          Satoranský     SG  28  CHI  65  28.9   3.6
# 143  144         Joe              Ingles     PF  32  UTA  72  29.7   3.4
# 144  145      Furkan             Korkmaz     SG  22  PHI  72  21.7   3.4
# 145  146    Markieff              Morris     PF  30  TOT  58  20.5   3.5
# 146  147    Mitchell            Robinson      C  21  NYK  61  23.1   4.1
# 147  148      Dorian        Finney-Smith     PF  26  DAL  71  29.9   3.4
# 148  149       Aaron             Holiday     PG  23  IND  66  24.5   3.5
# 149  150      George                Hill     PG  33  MIL  59  21.5   3.3
# 150  151  Kentavious       Caldwell-Pope     SG  26  LAL  69  25.5   3.4
# 151  152    Marquese              Chriss     PF  22  GSW  59  20.3   3.6
# 152  153     Michael              Porter     SF  21  DEN  55  16.4   3.5
# 153  154      Landry              Shamet     SG  22  LAC  53  27.4   3.0
# 154  155     Jarrett              Culver     SG  20  MIN  63  23.9   3.7
# 155  156       Donte          DiVincenzo     SG  23  MIL  66  23.0   3.5
# 156  157      Daniel               Theis      C  27  BOS  65  24.1   3.7
# 157  158       Mikal             Bridges     SF  23  PHO  73  28.0   3.4
# 158  159        Maxi              Kleber     PF  28  DAL  74  25.5   3.2
# 159  160     Derrick              Favors      C  28  NOP  51  24.4   4.1
# 160  161       Monte              Morris     PG  24  DEN  73  22.4   3.6
# 161  162  Sviatoslav          Mykhailiuk     SF  22  DET  56  22.6   3.0
# 162  163       Bruce               Brown     PG  23  DET  58  28.2   3.4
# 163  164        Gary               Trent     SF  21  POR  61  21.8   3.2
# 164  165        Kent            Bazemore     SF  30  TOT  68  24.8   2.9
# 165  166     Cameron             Johnson     PF  23  PHO  57  22.0   3.1
# 166  167      Jordan               Poole     SG  20  GSW  57  22.4   2.9
# 167  168      Austin              Rivers     SG  27  HOU  68  23.4   3.1
# 168  169        Josh              Okogie     SG  21  MIN  62  25.0   2.7
# 169  170     Derrick               Jones     SF  22  MIA  59  23.3   3.1
# 170  171      Justin             Holiday     SF  30  IND  73  25.0   2.8
# 171  172     DeAndre              Jordan      C  31  BRK  56  22.0   3.4
# 172  173     E'Twaun               Moore     SG  30  NOP  56  18.2   3.3
# 173  174    Anfernee              Simons     SG  20  POR  70  20.7   3.1
# 174  175       Ivica               Zubac      C  22  LAC  72  18.4   3.3
# 175  176       Jalen             Brunson     PG  23  DAL  57  17.9   3.2
# 176  177       Kelly              Olynyk      C  28  MIA  67  19.4   2.7
# 177  178        Enes              Kanter      C  27  BOS  58  16.9   3.4
# 178  179      Trevor               Ariza     SF  34  TOT  53  28.2   2.7
# 179  180       Danny               Green     SG  32  LAL  68  24.8   2.9
# 180  181        Alex                 Len      C  26  TOT  55  17.6   3.2
# 181  182        Tony               Snell     SF  28  DET  59  27.8   2.9
# 182  183     Patrick            Beverley     PG  31  LAC  51  26.3   2.9
# 183  184  De'Anthony              Melton     PG  21  MEM  60  19.5   2.7
# 184  185       Omari            Spellman      C  22  GSW  49  18.1   2.6
# 185  186     Terence               Davis     SG  22  TOR  72  16.8   2.8
# 186  187      Dwight              Howard      C  34  LAL  69  18.9   2.9
# 187  188     Bismack             Biyombo      C  27  CHO  53  19.4   2.8
# 188  189      Gorgui               Dieng      C  30  TOT  63  17.4   2.6
# 189  190      Jaxson               Hayes      C  19  NOP  64  16.9   2.7
# 190  191        Tyus               Jones     PG  23  MEM  65  19.0   3.0
# 191  192      Wesley            Matthews     SG  33  MIL  67  24.4   2.5
# 192  193     Nerlens                Noel      C  25  OKC  61  18.5   3.0
# 193  194        Kris                Dunn     PG  25  CHI  51  24.9   3.0
# 194  195    Emmanuel              Mudiay     PG  23  UTA  54  15.7   2.8
# 195  196      Willie        Cauley-Stein      C  26  TOT  54  20.3   3.2
# 196  197       Mason             Plumlee      C  29  DEN  61  17.3   2.9
# 197  198      Rondae    Hollis-Jefferson     PF  25  TOR  60  18.7   2.6
# 198  199        P.J.              Tucker     PF  34  HOU  72  34.3   2.5
# 199  200        Brad           Wanamaker     PG  30  BOS  71  19.3   2.3
# 200  201       Delon              Wright     PG  27  DAL  73  21.5   2.6
# 201  202    JaMychal               Green     PF  29  LAC  63  20.7   2.4
# 202  203     Damyean              Dotson     SG  25  NYK  48  17.4   2.5
# 203  204        Kyle              Korver     SF  38  MIL  58  16.6   2.2
# 204  205       Chris             Boucher      C  27  TOR  62  13.2   2.3
# 205  206       James               Ennis  SF-SG  29  TOT  69  18.3   2.3
# 206  207       Ersan            İlyasova     PF  32  MIL  63  15.7   2.3
# 207  208      JaVale               McGee      C  32  LAL  68  16.6   2.9
# 208  209      Nicolò               Melli      C  29  NOP  60  17.4   2.3
# 209  210        T.J.           McConnell     PG  27  IND  71  18.7   3.0
# 210  211        Cory              Joseph     PG  28  SAC  72  24.4   2.4
# 211  212       Kevin                Knox     SF  20  NYK  65  17.9   2.2
# 212  213        Trey               Lyles     PF  24  SAS  63  20.2   2.4
# 213  214      Lonnie              Walker     SG  21  SAS  61  16.2   2.5
# 214  215       Marco           Belinelli     SG  33  SAS  57  15.5   2.2
# 215  216       Frank             Jackson     PG  21  NOP  59  13.5   2.3
# 216  217       Abdel               Nader     SF  26  OKC  55  15.8   2.2
# 217  218       Frank           Ntilikina     PG  21  NYK  57  20.8   2.3
# 218  219       Royce             O'Neale     SF  26  UTA  71  28.9   2.2
# 219  220         Taj              Gibson      C  34  NYK  62  16.5   2.7
# 220  221        Mike               Scott     PF  31  PHI  68  17.8   2.2
# 221  222     Georges               Niang     PF  26  UTA  66  14.0   2.1
# 222  223      Marvin            Williams     PF  33  TOT  58  19.5   2.1
# 223  224        Kyle            Anderson     SF  26  MEM  67  19.9   2.3
# 224  225     Maurice            Harkless  PF-SF  26  TOT  62  23.0   2.3
# 225  226      Wesley              Iwundu     SF  25  ORL  52  18.3   1.9
# 226  227      Darius              Bazley     PF  19  OKC  61  18.5   2.0
# 227  228      Damian               Jones      C  24  ATL  55  16.1   2.2
# 228  229       Jakob              Poeltl      C  24  SAS  66  17.7   2.5
# 229  230        Alex              Caruso     PG  25  LAL  64  18.4   1.9
# 230  231     Solomon                Hill     PF  28  TOT  59  18.4   1.9
# 231  232      Justin             Jackson     PF  24  DAL  65  16.1   2.1
# 232  233          Mo               Bamba      C  21  ORL  62  14.2   2.1
# 233  234         Pat         Connaughton     SG  27  MIL  67  18.6   2.0
# 234  235      Torrey               Craig     SF  29  DEN  58  18.5   2.1
# 235  236       Robin               Lopez      C  31  MIL  66  14.5   2.2
# 236  237    Sterling               Brown     SF  24  MIL  52  14.8   1.8
# 237  238        Raul                Neto     PG  27  PHI  54  12.4   1.9
# 238  239      Jerome            Robinson     SG  22  TOT  63  15.5   1.8
# 239  240       Isaac               Bonga     SF  20  WAS  66  18.9   1.8
# 240  241       Vince              Carter     PF  43  ATL  60  14.6   1.8
# 241  242        Cody              Martin     SF  24  CHO  48  18.8   1.9
# 242  243        Tony             Bradley      C  22  UTA  58  11.4   2.2
# 243  244       Jevon              Carter     PG  24  PHO  58  16.3   1.7
# 244  245     Patrick           Patterson     PF  30  LAC  59  13.2   1.6
# 245  246       Mario             Hezonja     PF  24  POR  53  16.4   1.7
# 246  247        Thon               Maker      C  22  DET  60  12.9   1.6
# 247  248     Matisse            Thybulle     SG  22  PHI  65  19.8   1.7
# 248  249        Ryan         Arcidiacono     PG  25  CHI  58  16.0   1.6
# 249  250     Treveon              Graham     SF  26  TOT  55  16.9   1.6
# 250  251       Bruno            Fernando      C  21  ATL  56  12.7   1.8
# 251  252        Elie               Okobo     PG  22  PHO  55  13.1   1.3
# 252  253    Terrance            Ferguson     SF  21  OKC  56  22.4   1.4
# 253  254     Anthony            Tolliver     PF  34  TOT  55  15.9   1.2
# 254  255        Semi             Ojeleye     PF  25  BOS  69  14.7   1.2
# 255  256       Grant            Williams     PF  21  BOS  69  15.1   1.3
# 256  257      Rodney            McGruder     SG  28  LAC  56  15.6   1.3
# 257  258        Goga             Bitadze      C  20  IND  54   8.7   1.3
# 258  259     Matthew         Dellavedova     PG  29  CLE  57  14.4   1.1
#
#       FGA    FGP  THP  THPA   THPP  TWP  TWPA   TWPP    FT   FTA    FTP  ORB  \
# 0    22.3  0.444  4.4  12.4  0.355  5.5   9.9  0.556  10.2  11.8  0.865  1.0
# 1    22.9  0.455  3.0   8.4  0.353  7.4  14.4  0.515   6.8   8.0  0.842  0.9
# 36     Thaddeus               Young  31
# 37      DeAndre              Jordan  31
# 38      Patrick            Beverley  31
# 39         Mike               Scott  31
# 40        Robin               Lopez  31
# 41        James              Harden  30
# 42        DeMar             DeRozan  30
# 43        Bojan          Bogdanović  30
# 44        Jimmy              Butler  30
# 45       Marcus              Morris  30
# 46       Hassan           Whiteside  30
# 47        Serge               Ibaka  30
# 48         Eric             Bledsoe  30
# 49     Markieff              Morris  30
# 50         Kent            Bazemore  30
# 51       Justin             Holiday  30
# 52      E'Twaun               Moore  30
# 53       Gorgui               Dieng  30
# 54         Brad           Wanamaker  30
# 55      Patrick           Patterson  30
# 56       Damian             Lillard  29
# 57        Kemba              Walker  29
# 58       Nikola             Vučević  29
# 59         Jrue             Holiday  29
# 60       Gordon             Hayward  29
# 61         Will              Barton  29
# 62        Ricky               Rubio  29
# 63       Robert           Covington  29
# 64         Seth               Curry  29
# 65          Jae             Crowder  29
# 66        Mason             Plumlee  29
# 67     JaMychal               Green  29
# 68        James               Ennis  29
# 69       Nicolò               Melli  29
# 70       Torrey               Craig  29
# 71      Matthew         Dellavedova  29
# 72        Kawhi             Leonard  28
# 73           CJ            McCollum  28
# 74        Khris           Middleton  28
# 75         Alec               Burks  28
# 76     Terrence                Ross  28
# 77          Joe              Harris  28
# 78      Tristan            Thompson  28
# 79     Langston            Galloway  28
# 80         Doug           McDermott  28
# 81      Shabazz              Napier  28
# 82        Tomáš          Satoranský  28
# 83         Maxi              Kleber  28
# 84      Derrick              Favors  28
# 85        Kelly              Olynyk  28
# 86         Tony               Snell  28
# 87         Cory              Joseph  28
# 88      Solomon                Hill  28
# 89       Rodney            McGruder  28
# 90       Tobias              Harris  27
# 91        Buddy               Hield  27
# 92         Evan            Fournier  27
# 93      Malcolm             Brogdon  27
# 94          Tim            Hardaway  27
# 95        Dāvis             Bertāns  27
# 96       Jordan            Clarkson  27
# 97       Bogdan          Bogdanović  27
# 98         Rudy              Gobert  27
# 99        Jonas         Valančiūnas  27
# 100    Harrison              Barnes  27
# 101      Damion                 Lee  27
# 102        Cody              Zeller  27
# 103       Larry               Nance  27
# 104      Daniel               Theis  27
# 105      Austin              Rivers  27
# 106        Enes              Kanter  27
# 107     Bismack             Biyombo  27
# 108       Delon              Wright  27
# 109       Chris             Boucher  27
# 110        T.J.           McConnell  27
# 111         Pat         Connaughton  27
# 112        Raul                Neto  27
# 113     Bradley                Beal  26
# 114     Anthony               Davis  26
# 115     Spencer           Dinwiddie  26
# 116        T.J.              Warren  26
# 117      Dennis            Schröder  26
# 118    Montrezl             Harrell  26
# 119       Andre            Drummond  26
# 120      Norman              Powell  26
# 121        Josh          Richardson  26
# 122       Glenn            Robinson  26
# 123        Bryn              Forbes  26
# 124      Steven               Adams  26
# 125      Danuel               House  26
# 126         Ben            McLemore  26
# 127      Dorian        Finney-Smith  26
# 128  Kentavious       Caldwell-Pope  26
# 129        Alex                 Len  26
# 130      Willie        Cauley-Stein  26
# 131       Abdel               Nader  26
# 132       Royce             O'Neale  26
# 133     Georges               Niang  26
# 134        Kyle            Anderson  26
# 135     Maurice            Harkless  26
# 136     Treveon              Graham  26
# 137     Giannis       Antetokounmpo  25
# 138      Pascal              Siakam  25
# 139      Julius              Randle  25
# 140       Terry              Rozier  25
# 141        Fred            VanVleet  25
# 142      Duncan            Robinson  25
# 143      Marcus               Smart  25
# 144     Taurean              Prince  25
# 145      Jerami               Grant  25
# 146     Derrick               White  25
# 147       Dario               Šarić  25
# 148        Gary              Harris  25
# 149     Nerlens                Noel  25
# 150        Kris                Dunn  25
# 151      Rondae    Hollis-Jefferson  25
# 152     Damyean              Dotson  25
# 153      Wesley              Iwundu  25
# 154        Alex              Caruso  25
# 155        Ryan         Arcidiacono  25
# 156        Semi             Ojeleye  25
# 157        Zach              LaVine  24
# 158      Andrew             Wiggins  24
# 159    Kristaps           Porziņģis  24
# 160      Nikola               Jokić  24
# 161       Kelly               Oubre  24
# 162    Devonte'              Graham  24
# 163      Dillon              Brooks  24
# 164    Kendrick                Nunn  24
# 165       Aaron              Gordon  24
# 166   Christian                Wood  24
# 167        Kyle               Kuzma  24
# 168        Cedi               Osman  24
# 169        Josh                Hart  24
# 170       Bobby              Portis  24
# 171       Monte              Morris  24
# 172        Trey               Lyles  24
# 173      Damian               Jones  24
# 174       Jakob              Poeltl  24
# 175      Justin             Jackson  24
# 176    Sterling               Brown  24
# 177        Cody              Martin  24
# 178       Jevon              Carter  24
# 179       Mario             Hezonja  24
# 180       Devin              Booker  23
# 181     Donovan            Mitchell  23
# 182      Jaylen               Brown  23
# 183    Domantas             Sabonis  23
# 184         Ben             Simmons  23
# 185        Eric            Paschall  23
# 186     Brandon              Clarke  23
# 187       Myles              Turner  23
# 188       Malik             Beasley  23
# 189    Dejounte              Murray  23
# 190       Aaron             Holiday  23
# 191       Donte          DiVincenzo  23
# 192       Mikal             Bridges  23
# 193       Bruce               Brown  23
# 194     Cameron             Johnson  23
# 195       Jalen             Brunson  23
# 196        Tyus               Jones  23
# 197    Emmanuel              Mudiay  23
# 198     Brandon              Ingram  22
# 199    De'Aaron                 Fox  22
# 200       Jamal              Murray  22
# 201         Bam             Adebayo  22
# 202       Lauri           Markkanen  22
# 203    De'Andre              Hunter  22
# 204       Lonzo                Ball  22
# 205          OG             Anunoby  22
# 206      Furkan             Korkmaz  22
# 207    Marquese              Chriss  22
# 208      Landry              Shamet  22
# 209  Sviatoslav          Mykhailiuk  22
# 210     Derrick               Jones  22
# 211       Ivica               Zubac  22
# 212       Omari            Spellman  22
# 213     Terence               Davis  22
# 214      Jerome            Robinson  22
# 215        Tony             Bradley  22
# 216        Thon               Maker  22
# 217     Matisse            Thybulle  22
# 218        Elie               Okobo  22
# 219        Trae               Young  21
# 220      Jayson               Tatum  21
# 221      Collin              Sexton  21
# 222        Shai  Gilgeous-Alexander  21
# 223       Miles             Bridges  21
# 224       Kevin             Huerter  21
# 225        P.J.          Washington  21
# 226    Markelle               Fultz  21
# 227     Jarrett               Allen  21
# 228       Malik                Monk  21
# 229    Mitchell            Robinson  21
# 230     Michael              Porter  21
# 231        Gary               Trent  21
# 232        Josh              Okogie  21
# 233  De'Anthony              Melton  21
# 234      Lonnie              Walker  21
# 235       Frank             Jackson  21
# 236       Frank           Ntilikina  21
# 237          Mo               Bamba  21
# 238       Bruno            Fernando  21
# 239    Terrance            Ferguson  21
# 240       Grant            Williams  21
# 241        Luka              Dončić  20
# 242          Ja              Morant  20
# 243       Jaren             Jackson  20
# 244       Tyler               Herro  20
# 245      Darius             Garland  20
# 246         Cam             Reddish  20
# 247        Troy               Brown  20
# 248     Jarrett              Culver  20
# 249      Jordan               Poole  20
# 250    Anfernee              Simons  20
# 251       Kevin                Knox  20
# 252       Isaac               Bonga  20
# 253        Goga             Bitadze  20
# 254          RJ             Barrett  19
# 255        Coby               White  19
# 256       Kevin              Porter  19
# 257      Jaxson               Hayes  19
# 258      Darius              Bazley  19
# Please choose one of the following actions:
# Type "Show Tables" (without the quotations) in order to show the existing tables in the database.
# Type "Create Table" (without the quotations) in order to create a new table.
# Type "Drop Table" (without the quotations) in order to drop an existing table.
# Type "Create View" (without the quotations) in order to create a new view.
# Type "Update View" (without the quotations) in order to update an existing view.
# Type "Drop View" (without the quotations) in order to drop an existing view.
# Type "Insert" (without the quotations) in order to insert a new row into a table.
# Type "Update" (without the quotations) in order to update a row from a table.
# Type "Delete" (without the quotations) in order to delete a row from a table.
# Type "Select" (without the quotations) in order to search for specific rows in a table
# Type "Exit" (without the quotations) in order to exit the program and close the connection: Select
#
# Please type the name of the table you want to select rows from: nba_stats19_20
#
# Please type the SELECT condition: avg(age)
#
# Will you use a WHERE condition? Please type "Yes" or "No" (without the quotations).No
#
# Will you use a GROUP BY condition? Please type "Yes" or "No" (without the quotations).No
#
# Will you use an ORDER BY condition? Please type "Yes" or "No" (without the quotations).No
#
# The query you created is:
#
# SELECT avg(age) FROM nba_stats19_20
#   avg(age)
# 0  26.0849
# Please choose one of the following actions:
# Type "Show Tables" (without the quotations) in order to show the existing tables in the database.
# Type "Create Table" (without the quotations) in order to create a new table.
# Type "Drop Table" (without the quotations) in order to drop an existing table.
# Type "Create View" (without the quotations) in order to create a new view.
# Type "Update View" (without the quotations) in order to update an existing view.
# Type "Drop View" (without the quotations) in order to drop an existing view.
# Type "Insert" (without the quotations) in order to insert a new row into a table.
# Type "Update" (without the quotations) in order to update a row from a table.
# Type "Delete" (without the quotations) in order to delete a row from a table.
# Type "Select" (without the quotations) in order to search for specific rows in a table
# Type "Exit" (without the quotations) in order to exit the program and close the connection: Select
#
# Please type the name of the table you want to select rows from: *
#
# Please type the SELECT condition: dfsgd
#
# Will you use a WHERE condition? Please type "Yes" or "No" (without the quotations).No
#
# Will you use a GROUP BY condition? Please type "Yes" or "No" (without the quotations).No
#
# Will you use an ORDER BY condition? Please type "Yes" or "No" (without the quotations).No
#
# The query you created is:
#
# SELECT dfsgd FROM *
#
# There was an error in the query. Please try again.
#
# Please choose one of the following actions:
# Type "Show Tables" (without the quotations) in order to show the existing tables in the database.
# Type "Create Table" (without the quotations) in order to create a new table.
# Type "Drop Table" (without the quotations) in order to drop an existing table.
# Type "Create View" (without the quotations) in order to create a new view.
# Type "Update View" (without the quotations) in order to update an existing view.
# Type "Drop View" (without the quotations) in order to drop an existing view.
# Type "Insert" (without the quotations) in order to insert a new row into a table.
# Type "Update" (without the quotations) in order to update a row from a table.
# Type "Delete" (without the quotations) in order to delete a row from a table.
# Type "Select" (without the quotations) in order to search for specific rows in a table
# Type "Exit" (without the quotations) in order to exit the program and close the connection: Select
#
# Please type the name of the table you want to select rows from: nba_stats19_20
#
# Please type the SELECT condition: *
#
# Will you use a WHERE condition? Please type "Yes" or "No" (without the quotations).Yes
#
# Please type the WHERE condition: PTS >()
#
# Please type the name of the table you want to select rows from: nba_stats19_20
#
# Please type the SELECT condition: PTS
#
# Will you use a WHERE condition? Please type "Yes" or "No" (without the quotations).Yes
#
# Please type the WHERE condition: name='Giannis'
#
# Will you use a GROUP BY condition? Please type "Yes" or "No" (without the quotations).No
#
# Will you use an ORDER BY condition? Please type "Yes" or "No" (without the quotations).No
#
# Will you use a GROUP BY condition? Please type "Yes" or "No" (without the quotations).No
#
# Will you use an ORDER BY condition? Please type "Yes" or "No" (without the quotations).No
#
# The query you created is:
#
# SELECT * FROM nba_stats19_20 WHERE PTS >(SELECT PTS FROM nba_stats19_20 WHERE name='Giannis'   )
#   ID     Name  Surname Pos Age   Tm   G    MP    FG   FGA    FGP  THP  THPA  \
# 0  1    James   Harden  SG  30  HOU  68  36.5   9.9  22.3  0.444  4.4  12.4
# 1  2  Bradley     Beal  SG  26  WAS  57  36.0  10.4  22.9  0.455  3.0   8.4
# 2  3   Damian  Lillard  PG  29  POR  66  37.5   9.5  20.4  0.463  4.1  10.2
# 3  4     Trae    Young  PG  21  ATL  60  35.3   9.1  20.8  0.437  3.4   9.5
#
#     THPP  TWP  TWPA   TWPP    FT   FTA    FTP  ORB  DRB  TRB  AST  STL  BLK  \
# 0  0.355  5.5   9.9  0.556  10.2  11.8  0.865  1.0  5.5  6.6  7.5  1.8  0.9
# 1  0.353  7.4  14.4  0.515   6.8   8.0  0.842  0.9  3.3  4.2  6.1  1.2  0.4
# 2  0.401  5.4  10.2  0.524   7.0   7.8  0.888  0.5  3.8  4.3  8.0  1.1  0.3
# 3  0.361  5.7  11.4  0.501   8.0   9.3   0.86  0.5  3.7  4.3  9.3  1.1  0.1
#
#    TOV   PF   PTS
# 0  4.5  3.3  34.3
# 1  3.4  2.2  30.5
# 2  2.9  1.7  30.0
# 3  4.8  1.7  29.6
# Please choose one of the following actions:
# Type "Show Tables" (without the quotations) in order to show the existing tables in the database.
# Type "Create Table" (without the quotations) in order to create a new table.
# Type "Drop Table" (without the quotations) in order to drop an existing table.
# Type "Create View" (without the quotations) in order to create a new view.
# Type "Update View" (without the quotations) in order to update an existing view.
# Type "Drop View" (without the quotations) in order to drop an existing view.
# Type "Insert" (without the quotations) in order to insert a new row into a table.
# Type "Update" (without the quotations) in order to update a row from a table.
# Type "Delete" (without the quotations) in order to delete a row from a table.
# Type "Select" (without the quotations) in order to search for specific rows in a table
# Type "Exit" (without the quotations) in order to exit the program and close the connection: Exit
#
# Thank you for using our ChatBot. Have a nice day!
